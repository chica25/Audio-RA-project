# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series
from scipy import stats
# Out:
# /Users/pcordero/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# TODO: load `data/processed/shopping_cleaned.csv` as a pandas dataframe

df = pd.read_csv("../data/cleaned_music_data.csv", usecols=['artist_name', 'track_name', 'release_date', 'genre', 'dating', 'violence', 'world/life', 'night/time',
       'shake the audience', 'family/gospel', 'romantic', 'communication',
       'obscene', 'music', 'movement/places', 'light/visual perceptions',
       'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
       'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy',
       'topic', 'age'])

df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre    dating  violence  world/life  night/time  \
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28372 entries, 0 to 28371
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   artist_name               28372 non-null  object
#  1   track_name                28372 non-null  object
#  2   release_date              28372 non-null  int64
#  3   genre                     28372 non-null  object
#  4   dating                    28372 non-null  float64
#  5   violence                  28372 non-null  float64
#  6   world/life                28372 non-null  float64
#  7   night/time                28372 non-null  float64
#  8   shake the audience        28372 non-null  float64
#  9   family/gospel             28372 non-null  float64
#  10  romantic                  28372 non-null  float64
#  11  communication             28372 non-null  float64
#  12  obscene                   28372 non-null  float64
# ...

# %%
# Displays all the rows and columns of the dataframe.
df.shape
# Out:
# (28372, 28)

# %%
# Renaming the columns
df = df.rename(columns={'artist_name':'Artist_Name',
                    'track_name':'Track_Name',
                    'release_date':'Release_Date',
                    'genre':'Genre',
                    'dating':'Dating',
                    'violence':'Violence',
                    'world/life':'World/life',
                    'night/time':'Night/Time',
                    'shake the audience':'Shake the Audience',
                    'family/gospel':'Family/Gospel',
                    'romantic':'Romantic',
                    'communication':'Communication',
                    'obscene':'Obscene',
                    'music':'Music',
                    'movement/places':'Movement/Places',
                    'light/visual perceptions': 'Light/Visual Perceptions',
                    'family/spiritual':'Family/Spiritual',
                    'like/girls':'Like/Girls',
                    'sadness':'Sadness',
                    'feelings':'Feelings',
                    'danceability':'Danceability',
                    'loudness':'Loudness',
                    'acousticness':'Acousticness','instrumentalness':'Instrumentalness',
                    'valence':'Valence',
                    'energy':'Energy',
                    'topic':'Topic',
                    'age':'Age'
                    })

# %%
df.columns
# Out:
# Index(['Artist_Name', 'Track_Name', 'Release_Date', 'Genre', 'Dating',
#        'Violence', 'World/life', 'Night/Time', 'Shake the Audience',
#        'Family/Gospel', 'Romantic', 'Communication', 'Obscene', 'Music',
#        'Movement/Places', 'Light/Visual Perceptions', 'Family/Spiritual',
#        'Like/Girls', 'Sadness', 'Feelings', 'Danceability', 'Loudness',
#        'Acousticness', 'Instrumentalness', 'Valence', 'Energy', 'Topic',
#        'Age'],
#       dtype='object')

# %%
df.head()
# Out:
#             Artist_Name            Track_Name  Release_Date Genre    Dating  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop  0.000598
# 1         frankie laine             i believe          1950   pop  0.035537
# 2           johnnie ray                   cry          1950   pop  0.002770
# 3           pérez prado              patricia          1950   pop  0.048249
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop  0.001350
#
#    Violence  World/life  Night/Time  Shake the Audience  Family/Gospel  ...  \
# 0  0.063746    0.000598    0.000598            0.000598       0.048857  ...
# 1  0.096777    0.443435    0.001284            0.001284       0.027007  ...
# 2  0.002770    0.002770    0.002770            0.002770       0.002770  ...
# 3  0.001548    0.001548    0.001548            0.021500       0.001548  ...
# 4  0.001350    0.417772    0.001350            0.001350       0.001350  ...
#
# ...

# %%
(df['Release_Date'].isnull()).value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 28367    False
# 28368    False
# 28369    False
# 28370    False
# 28371    False
# Name: Release_Date, Length: 28372, dtype: bool>

# %%
#Checking to see if there are any duplicates
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Artist_Name, Track_Name, Release_Date, Genre, Dating, Violence, World/life, Night/Time, Shake the Audience, Family/Gospel, Romantic, Communication, Obscene, Music, Movement/Places, Light/Visual Perceptions, Family/Spiritual, Like/Girls, Sadness, Feelings, Danceability, Loudness, Acousticness, Instrumentalness, Valence, Energy, Topic, Age]
# Index: []
#
# [0 rows x 28 columns]
