# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series
from scipy import stats

# %%
# TODO: load `data/processed/shopping_cleaned.csv` as a pandas dataframe

df = pd.read_csv("../data/cleaned_music_data.csv", usecols=['dating', 'violence', 'world/life', 'night/time',
       'shake the audience', 'family/gospel', 'romantic', 'communication',
       'obscene', 'music', 'movement/places', 'light/visual perceptions',
       'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
       'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy',
      'age'])

df
# Out:
#          dating  violence  world/life  night/time  shake the audience  \
# 0      0.000598  0.063746    0.000598    0.000598            0.000598
# 1      0.035537  0.096777    0.443435    0.001284            0.001284
# 2      0.002770  0.002770    0.002770    0.002770            0.002770
# 3      0.048249  0.001548    0.001548    0.001548            0.021500
# 4      0.001350  0.001350    0.417772    0.001350            0.001350
# ...         ...       ...         ...         ...                 ...
# 28367  0.001350  0.001350    0.001350    0.001350            0.001350
# 28368  0.001284  0.001284    0.035338    0.001284            0.001284
# 28369  0.001504  0.154302    0.168988    0.001504            0.039755
# 28370  0.001196  0.001196    0.001196    0.001196            0.048359
# 28371  0.001012  0.075202    0.001012    0.001012            0.001012
#
#        family/gospel  romantic  communication   obscene     music  ...  \
# 0           0.048857  0.017104       0.263751  0.000598  0.039288  ...
# 1           0.027007  0.001284       0.001284  0.001284  0.118034  ...
# 2           0.002770  0.158564       0.250668  0.002770  0.323794  ...
# 3           0.001548  0.411536       0.001548  0.001548  0.001548  ...
# 4           0.001350  0.463430       0.001350  0.001350  0.001350  ...
# ...              ...       ...            ...       ...       ...  ...
# 28367       0.001350  0.001350       0.001350  0.391651  0.001350  ...
# 28368       0.001284  0.066324       0.203889  0.318910  0.058152  ...
# 28369       0.001504  0.035401       0.001504  0.356685  0.001504  ...
# 28370       0.001196  0.001196       0.001196  0.492434  0.103614  ...
# 28371       0.001012  0.001012       0.001012  0.754444  0.046284  ...
#
#        like/girls   sadness  feelings  danceability  loudness  acousticness  \
# 0        0.000598  0.380299  0.117175      0.357739  0.454119      0.997992
# 1        0.001284  0.001284  0.001284      0.331745  0.647540      0.954819
# 2        0.002770  0.002770  0.225422      0.456298  0.585288      0.840361
# 3        0.081132  0.225889  0.001548      0.686992  0.744404      0.083935
# 4        0.001350  0.068800  0.001350      0.291671  0.646489      0.975904
# ...           ...       ...       ...           ...       ...           ...
# 28367    0.001350  0.065664  0.001350      0.889527  0.759711      0.062549
# 28368    0.040811  0.001284  0.001284      0.662082  0.789580      0.004607
# 28369    0.001504  0.001504  0.001504      0.663165  0.726970      0.104417
# 28370    0.070867  0.001196  0.001196      0.883028  0.786888      0.007027
# 28371    0.001012  0.001012  0.033995      0.828875  0.674794      0.015862
#
#        instrumentalness   valence    energy       age
# 0              0.901822  0.339448  0.137110  1.000000
# 1              0.000002  0.325021  0.263240  1.000000
# 2              0.000000  0.351814  0.139112  1.000000
# 3              0.199393  0.775350  0.743736  1.000000
# 4              0.000246  0.597073  0.394375  1.000000
# ...                 ...       ...       ...       ...
# 28367          0.000000  0.751649  0.695686  0.014286
# 28368          0.000002  0.922712  0.797791  0.014286
# 28369          0.000001  0.838211  0.767761  0.014286
# 28370          0.000503  0.508450  0.885882  0.014286
# 28371          0.000000  0.475474  0.492477  0.014286
#
# [28372 rows x 23 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28372 entries, 0 to 28371
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   dating                    28372 non-null  float64
#  1   violence                  28372 non-null  float64
#  2   world/life                28372 non-null  float64
#  3   night/time                28372 non-null  float64
#  4   shake the audience        28372 non-null  float64
#  5   family/gospel             28372 non-null  float64
#  6   romantic                  28372 non-null  float64
#  7   communication             28372 non-null  float64
#  8   obscene                   28372 non-null  float64
#  9   music                     28372 non-null  float64
#  10  movement/places           28372 non-null  float64
#  11  light/visual perceptions  28372 non-null  float64
#  12  family/spiritual          28372 non-null  float64
#  13  like/girls                28372 non-null  float64
#  14  sadness                   28372 non-null  float64
#  15  feelings                  28372 non-null  float64
#  16  danceability              28372 non-null  float64
#  17  loudness                  28372 non-null  float64
#  18  acousticness              28372 non-null  float64
#  19  instrumentalness          28372 non-null  float64
#  20  valence                   28372 non-null  float64
#  21  energy                    28372 non-null  float64
#  22  age                       28372 non-null  float64
# dtypes: float64(23)
# memory usage: 5.0 MB

# %%
# Displays all the rows and columns of the dataframe.
df.shape
# Out:
# (28372, 23)

# %%
# Renaming the columns
df = df.rename(columns={'dating':'Dating',
                    'violence':'Violence',
                    'world/life':'World/life',
                    'night/time':'Night/Time',
                    'shake the audience':'Shake the Audience',
                    'family/gospel':'Family/Gospel',
                    'romantic':'Romantic',
                    'communication':'Communication',
                    'obscene':'Obscene',
                    'music':'Music',
                    'movement/places':'Movement/Places',
                    'light/visual perceptions': 'Light/Visual Perceptions',
                    'family/spiritual':'Family/Spiritual',
                    'like/girls':'Like/Girls',
                    'sadness':'Sadness',
                    'feelings':'Feelings',
                    'danceability':'Danceability',
                    'loudness':'Loudness',
                    'acousticness':'Acousticness','instrumentalness':'Instrumentalness',
                    'valence':'Valence',
                    'energy':'Energy',
                    'age':'Age'
                    })

# %%
df.columns
# Out:
# Index(['Dating', 'Violence', 'World/life', 'Night/Time', 'Shake the Audience',
#        'Family/Gospel', 'Romantic', 'Communication', 'Obscene', 'Music',
#        'Movement/Places', 'Light/Visual Perceptions', 'Family/Spiritual',
#        'Like/Girls', 'Sadness', 'Feelings', 'Danceability', 'Loudness',
#        'Acousticness', 'Instrumentalness', 'Valence', 'Energy', 'Age'],
#       dtype='object')

# %%
df.head()
# Out:
#      Dating  Violence  World/life  Night/Time  Shake the Audience  \
# 0  0.000598  0.063746    0.000598    0.000598            0.000598
# 1  0.035537  0.096777    0.443435    0.001284            0.001284
# 2  0.002770  0.002770    0.002770    0.002770            0.002770
# 3  0.048249  0.001548    0.001548    0.001548            0.021500
# 4  0.001350  0.001350    0.417772    0.001350            0.001350
#
#    Family/Gospel  Romantic  Communication   Obscene     Music  ...  \
# 0       0.048857  0.017104       0.263751  0.000598  0.039288  ...
# 1       0.027007  0.001284       0.001284  0.001284  0.118034  ...
# 2       0.002770  0.158564       0.250668  0.002770  0.323794  ...
# 3       0.001548  0.411536       0.001548  0.001548  0.001548  ...
# 4       0.001350  0.463430       0.001350  0.001350  0.001350  ...
#
#    Like/Girls   Sadness  Feelings  Danceability  Loudness  Acousticness  \
# 0    0.000598  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.001284  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.081132  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.001350  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    Instrumentalness   Valence    Energy  Age
# 0          0.901822  0.339448  0.137110  1.0
# 1          0.000002  0.325021  0.263240  1.0
# 2          0.000000  0.351814  0.139112  1.0
# 3          0.199393  0.775350  0.743736  1.0
# 4          0.000246  0.597073  0.394375  1.0
#
# [5 rows x 23 columns]

# %%
# Checking to see if there are any duplicates
# df.loc.duplicated()

# %%
df.head()
# Out:
#      Dating  Violence  World/life  Night/Time  Shake the Audience  \
# 0  0.000598  0.063746    0.000598    0.000598            0.000598
# 1  0.035537  0.096777    0.443435    0.001284            0.001284
# 2  0.002770  0.002770    0.002770    0.002770            0.002770
# 3  0.048249  0.001548    0.001548    0.001548            0.021500
# 4  0.001350  0.001350    0.417772    0.001350            0.001350
#
#    Family/Gospel  Romantic  Communication   Obscene     Music  ...  \
# 0       0.048857  0.017104       0.263751  0.000598  0.039288  ...
# 1       0.027007  0.001284       0.001284  0.001284  0.118034  ...
# 2       0.002770  0.158564       0.250668  0.002770  0.323794  ...
# 3       0.001548  0.411536       0.001548  0.001548  0.001548  ...
# 4       0.001350  0.463430       0.001350  0.001350  0.001350  ...
#
#    Like/Girls   Sadness  Feelings  Danceability  Loudness  Acousticness  \
# 0    0.000598  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.001284  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.081132  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.001350  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    Instrumentalness   Valence    Energy  Age
# 0          0.901822  0.339448  0.137110  1.0
# 1          0.000002  0.325021  0.263240  1.0
# 2          0.000000  0.351814  0.139112  1.0
# 3          0.199393  0.775350  0.743736  1.0
# 4          0.000246  0.597073  0.394375  1.0
#
# [5 rows x 23 columns]

# %%
new_df = df.to_csv("../data/cleaned_music_data.csv")
